# %%
from data_process import *
from model import *

# %%
write_csv(number_of_years=2, force=True)

# %%
df = csv_to_dataframe()

# %%
df.head()
# Out:
#          date  hour  day_of_week  price_euros_mwh
# 0  2020-12-31    23            3            50.87
# 1  2021-01-01     0            4            48.19
# 2  2021-01-01     1            4            44.68
# 3  2021-01-01     2            4            42.92
# 4  2021-01-01     3            4            40.39

# %% [markdown]
# ### Day-ahead prediction

# %%
WNN_regressor_model = WNN_electricity_price_predictor()
WNN_regressor_model.set_train_test_sets(df, 1)
WNN_regressor_model.train()
WNN_regressor_model.evaluate()
# Out:
# Number of tests : 2502
# RMSE total : 8.735031518125801
# RMSE min : 3.0032139369861346
# RMSE max : 26.533650011204145
#          99%        95%        90%        75%        50%
# 0  15.027978  53.876898  76.059153  93.045564  97.282174
#          99%        95%       90%        75%        50%
# 0  55.915268  76.059153  86.85052  95.963229  98.161471

# %% [markdown]
# ### Month-ahead prediction

# %%
WNN_regressor_model = WNN_electricity_price_predictor()
WNN_regressor_model.set_train_test_sets(df, 31)
WNN_regressor_model.train()
WNN_regressor_model.evaluate()
# Out:
# Number of tests : 2358
# RMSE total : 8.106060834390888
# RMSE min : 2.9634697110487065
# RMSE max : 20.227653867853082
#
#          99%        95%        90%        75%        50%
# 0  15.733673  55.937235  76.717557  93.469042  97.158609
#          99%        95%        90%        75%        50%
# 0  56.530958  77.947413  87.277354  96.013571  98.134012
